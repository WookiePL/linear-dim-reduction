# %%
from summary_report import SummaryReport
sr_df = SummaryReport('2018-11-03 141716')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-000dc1ffc74f> in <module>
# ----> 1 from summary_report import SummaryReport
#       2 sr_df = SummaryReport('2018-11-03 141716')
#
# D:\private-projects\linear-dim-reduction\summary_report\summary_report.py in <module>
#       2 import os
#       3 from pprint import pprint
# ----> 4 from report_model.output_report import OutputReport
#       5 import pandas as pd
#       6
#
# ModuleNotFoundError: No module named 'report_model'

# %%
from summary_report import SummaryReport
sr_df = SummaryReport('2018-11-03 141716')

# %%
sr_df

# %%
sr_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f41882625a1d> in <module>
# ----> 1 sr_df.head()
#
# AttributeError: 'SummaryReport' object has no attribute 'head'

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-03 141716')

# %%
report_df
# Out:
#    accuracy                                        conf_matrix  \
# 0  0.654545  [[27, 0, 0, 0, 0, 0], [1, 19, 0, 0, 0, 0], [0,...
# 1  0.727273  [[27, 0, 0, 0, 0, 0], [1, 19, 0, 0, 0, 0], [0,...
# 2  0.600000  [[27, 0, 0, 0, 0, 0], [2, 15, 3, 0, 0, 0], [0,...
# 3  0.836364  [[27, 0, 0, 0, 0, 0], [1, 19, 0, 0, 0, 0], [0,...
# 4  0.827273  [[27, 0, 0, 0, 0, 0], [1, 19, 0, 0, 0, 0], [0,...
# 5  0.981818  [[27, 0, 0, 0, 0, 0], [1, 18, 0, 1, 0, 0], [0,...
#
#   conf_matrix_png_url     error  f1_score  \
# 0                      0.736364  0.654545
# 1                      0.627273  0.727273
# 2                      1.090909  0.600000
# 3                      0.300000  0.836364
# 4                      0.336364  0.827273
# 5                      0.027273  0.981818
#
#                                         input_params  \
# 0  {'script_name': 'derm_pca3_reduction.py', 'dat...
# 1  {'script_name': 'derm_lda1_reduction.py', 'dat...
# 2  {'script_name': 'derm_nmf1_reduction.py', 'dat...
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-03 141716')
sr.gen_docx_from_df(report_df)
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-1-e9b761f339c8> in <module>
#       2 sr = SummaryReport()
#       3 report_df = sr.generate_summary_report(run_id='2018-11-03 141716')
# ----> 4 sr.gen_docx_from_df(report_df)
#
# D:\private-projects\linear-dim-reduction\summary_report\summary_report.py in gen_docx_from_df(self, df)
#      55
#      56         # open an existing document
# ---> 57         doc = docx.Document('D:\\private-projects\\linear-dim-reduction\\summary_report\\test.docx')
#      58
#      59         # add a table to the end and create a reference variable
#
# d:\private-projects\venv\lib\site-packages\docx\api.py in Document(docx)
#      23     """
#      24     docx = _default_docx_path() if docx is None else docx
# ---> 25     document_part = Package.open(docx).main_document_part
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()

# %%
report_df = sr.generate_summary_report(run_id='2018-11-05 115020')
pretty_report_df = sr.make_report_pretty(report_df)

# %%
pretty_report_df
# Out:
#                       Metoda  Liczba składowych Klasyfikator  Dokładność  \
# 0     derm_pca3_reduction.py                2.0           lr    0.654545
# 1     derm_lda1_reduction.py                2.0           lr    0.727273
# 2     derm_nmf1_reduction.py                2.0           lr    0.600000
# 3     derm_pca3_reduction.py                4.0           lr    0.836364
# 4     derm_lda1_reduction.py                4.0           lr    0.827273
# 5  derm_without_reduction.py                NaN           lr    0.981818
#
#        Błąd  Precyzja   Pełność  Wynik F1
# 0  0.736364  0.654545  0.654545  0.654545
# 1  0.627273  0.727273  0.727273  0.727273
# 2  1.090909  0.600000  0.600000  0.600000
# 3  0.300000  0.836364  0.836364  0.836364
# 4  0.336364  0.827273  0.827273  0.827273
# 5  0.027273  0.981818  0.981818  0.981818

# %%
pretty_report_df['Liczba składowych'].round(0)
pretty_report_df['Liczba składowych'] = pretty_report_df['Liczba składowych'].astype(str)

# %%
pretty_report_df

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 115020')
pretty_report_df = sr.make_report_pretty(report_df)
roundings = pd.Series([0, 2, 2, 2, 2, 2], index=['Liczba składowych', 'Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
pretty_report_df['Liczba składowych'].round(0)
pretty_report_df['Liczba składowych'] = pretty_report_df['Liczba składowych'].astype(str)
pretty_report_df
# Out:
# d:\private-projects\venv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Metoda Liczba składowych          Klasyfikator  Dokładność      Błąd  \
# 0           PCA               2.0  Regresja logistyczna    0.654545  0.736364
# 1           LDA               2.0  Regresja logistyczna    0.727273  0.627273
# 2           NMF               2.0  Regresja logistyczna    0.600000  1.090909
# 3           PCA               4.0  Regresja logistyczna    0.836364  0.300000
# 4           LDA               4.0  Regresja logistyczna    0.827273  0.336364
# 5  Bez redukcji               nan  Regresja logistyczna    0.981818  0.027273
#
#    Precyzja   Pełność  Wynik F1
# 0  0.654545  0.654545  0.654545
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 115020')
pretty_report_df = sr.make_report_pretty(report_df)
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
pretty_report_df
# Out:
#          Metoda  Liczba składowych          Klasyfikator  Dokładność  \
# 0           PCA                2.0  Regresja logistyczna    0.654545
# 1           LDA                2.0  Regresja logistyczna    0.727273
# 2           NMF                2.0  Regresja logistyczna    0.600000
# 3           PCA                4.0  Regresja logistyczna    0.836364
# 4           LDA                4.0  Regresja logistyczna    0.827273
# 5  Bez redukcji                NaN  Regresja logistyczna    0.981818
#
#        Błąd  Precyzja   Pełność  Wynik F1
# 0  0.736364  0.654545  0.654545  0.654545
# 1  0.627273  0.727273  0.727273  0.727273
# 2  1.090909  0.600000  0.600000  0.600000
# 3  0.300000  0.836364  0.836364  0.836364
# 4  0.336364  0.827273  0.827273  0.827273
# 5  0.027273  0.981818  0.981818  0.981818

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 115020')
pretty_report_df = sr.make_report_pretty(report_df)

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
pretty_report_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7f652575301> in <module>
#       1 import pandas as pd
#       2 roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
# ----> 3 pretty_report_df.round(roundings)
#       4 pretty_report_df
#
# NameError: name 'pretty_report_df' is not defined

# %%
pretty_report_df
# Out:
#          Metoda  Liczba składowych          Klasyfikator  Dokładność  \
# 0           PCA                2.0  Regresja logistyczna    0.654545
# 1           LDA                2.0  Regresja logistyczna    0.727273
# 2           NMF                2.0  Regresja logistyczna    0.600000
# 3           PCA                4.0  Regresja logistyczna    0.836364
# 4           LDA                4.0  Regresja logistyczna    0.827273
# 5  Bez redukcji                NaN  Regresja logistyczna    0.981818
#
#        Błąd  Precyzja   Pełność  Wynik F1
# 0  0.736364  0.654545  0.654545  0.654545
# 1  0.627273  0.727273  0.727273  0.727273
# 2  1.090909  0.600000  0.600000  0.600000
# 3  0.300000  0.836364  0.836364  0.836364
# 4  0.336364  0.827273  0.827273  0.827273
# 5  0.027273  0.981818  0.981818  0.981818

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 115020')
pretty_report_df = sr.make_report_pretty(report_df)

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
#          Metoda  Liczba składowych          Klasyfikator  Dokładność  Błąd  \
# 0           PCA                2.0  Regresja logistyczna        0.65  0.74
# 1           LDA                2.0  Regresja logistyczna        0.73  0.63
# 2           NMF                2.0  Regresja logistyczna        0.60  1.09
# 3           PCA                4.0  Regresja logistyczna        0.84  0.30
# 4           LDA                4.0  Regresja logistyczna        0.83  0.34
# 5  Bez redukcji                NaN  Regresja logistyczna        0.98  0.03
#
#    Precyzja  Pełność  Wynik F1
# 0      0.65     0.65      0.65
# 1      0.73     0.73      0.73
# 2      0.60     0.60      0.60
# 3      0.84     0.84      0.84
# 4      0.83     0.83      0.83
# 5      0.98     0.98      0.98

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3db37b617cd> in <module>
#       1 import pandas as pd
#       2 roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
# ----> 3 pretty_report_df.round(roundings)
#
# NameError: name 'pretty_report_df' is not defined

# %%
report_df = sr.generate_summary_report(run_id='2018-11-05 132025')
pretty_report_df = sr.make_report_pretty(report_df)
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
#           Metoda  Liczba składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2.0  Regresja logistyczna        0.65  0.74
# 1            LDA                2.0  Regresja logistyczna        0.73  0.63
# 2            NMF                2.0  Regresja logistyczna        0.60  1.09
# 3            PCA                4.0  Regresja logistyczna        0.84  0.30
# 4            LDA                4.0  Regresja logistyczna        0.83  0.34
# 5            NMF                4.0  Regresja logistyczna        0.77  0.61
# 6            PCA                2.0                   SVM        0.78  0.50
# 7            LDA                2.0                   SVM        0.84  0.34
# 8            NMF                2.0                   SVM        0.70  0.62
# 9            PCA                4.0                   SVM        0.87  0.34
# 10           LDA                4.0                   SVM        0.85  0.43
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)

# %%
import pandas as pd
roundings = pd.Series([0, 2, 2, 2, 2, 2], index=['Liczba składowych', 'Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
#           Metoda  Liczba składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2.0  Regresja logistyczna        0.65  0.74
# 1            LDA                2.0  Regresja logistyczna        0.73  0.63
# 2            NMF                2.0  Regresja logistyczna        0.60  1.09
# 3            PCA                4.0  Regresja logistyczna        0.84  0.30
# 4            LDA                4.0  Regresja logistyczna        0.83  0.34
# 5            NMF                4.0  Regresja logistyczna        0.77  0.61
# 6            PCA                2.0                   SVM        0.78  0.50
# 7            LDA                2.0                   SVM        0.84  0.34
# 8            NMF                2.0                   SVM        0.70  0.62
# 9            PCA                4.0                   SVM        0.87  0.34
# 10           LDA                4.0                   SVM        0.85  0.43
# ...

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = pretty_report_df.style.background_gradient(cmap=cm)

# %%
s
# Out:
# d:\private-projects\venv\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_00aabbac_e10b_11e8_9101_80ce6226d47arow0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow0_col3 {
#             background-color:  #c5edc5;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow0_col4 {
#             background-color:  #4daa4d;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow0_col5 {
#             background-color:  #c5edc5;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow0_col6 {
#             background-color:  #c5edc5;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow0_col7 {
#             background-color:  #c5edc5;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_00aabbac_e10b_11e8_9101_80ce6226d47arow1_col3 {
# ...

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = pretty_report_df.style.background_gradient(cmap=cm)

# %%
s
# Out:
# <style  type="text/css" >
#     #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow0_col3 {
#             background-color:  #c5edc5;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow0_col4 {
#             background-color:  #4daa4d;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow0_col5 {
#             background-color:  #c5edc5;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow0_col6 {
#             background-color:  #c5edc5;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow0_col7 {
#             background-color:  #c5edc5;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow1_col3 {
#             background-color:  #99d599;
#         }    #T_2aa4b364_e10b_11e8_b7de_80ce6226d47arow1_col4 {
#             background-color:  #64b764;
# ...

# %%
import seaborn as sns

cm = sns.light_palette("grey", as_cmap=True)

s = pretty_report_df.style.background_gradient(cmap=cm)

# %%
s
# Out:
# <style  type="text/css" >
#     #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow0_col1 {
#             background-color:  #f2f2f2;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow0_col3 {
#             background-color:  #e2e2e2;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow0_col4 {
#             background-color:  #a6a6a6;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow0_col5 {
#             background-color:  #e2e2e2;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow0_col6 {
#             background-color:  #e2e2e2;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow0_col7 {
#             background-color:  #e2e2e2;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow1_col1 {
#             background-color:  #f2f2f2;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow1_col3 {
#             background-color:  #cccccc;
#         }    #T_3239cb6c_e10b_11e8_bd45_80ce6226d47arow1_col4 {
#             background-color:  #b2b2b2;
# ...

# %%
import seaborn as sns

cm = sns.light_palette("grey", as_cmap=True, alpha=0.3)

s = pretty_report_df.style.background_gradient(cmap=cm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-593794770fe2> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 cm = sns.light_palette("grey", as_cmap=True, alpha=0.3)
#       4
#       5 s = pretty_report_df.style.background_gradient(cmap=cm)
#
# TypeError: light_palette() got an unexpected keyword argument 'alpha'

# %%
import seaborn as sns

cm = sns.light_palette("grey", as_cmap=True, scatter_kws={'alpha':0.3})

s = pretty_report_df.style.background_gradient(cmap=cm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-eb58c7342aed> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 cm = sns.light_palette("grey", as_cmap=True, scatter_kws={'alpha':0.3})
#       4
#       5 s = pretty_report_df.style.background_gradient(cmap=cm)
#
# TypeError: light_palette() got an unexpected keyword argument 'scatter_kws'

# %%
import seaborn as sns

cm = sns.pastel_palette("grey", as_cmap=True, alpha=0.3)

s = pretty_report_df.style.background_gradient(cmap=cm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-6c1d2c1e402f> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 cm = sns.pastel_palette("grey", as_cmap=True, alpha=0.3)
#       4
#       5 s = pretty_report_df.style.background_gradient(cmap=cm)
#
# AttributeError: module 'seaborn' has no attribute 'pastel_palette'

# %%
import seaborn as sns

cm = sns.light_palette("grey", as_cmap=True)

pretty_report_df = pretty_report_df.style.background_gradient(cmap=cm)

# %%
pretty_report_df
# Out:
# <style  type="text/css" >
#     #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow0_col1 {
#             background-color:  #f2f2f2;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow0_col3 {
#             background-color:  #e2e2e2;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow0_col4 {
#             background-color:  #a6a6a6;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow0_col5 {
#             background-color:  #e2e2e2;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow0_col6 {
#             background-color:  #e2e2e2;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow0_col7 {
#             background-color:  #e2e2e2;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow1_col1 {
#             background-color:  #f2f2f2;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow1_col3 {
#             background-color:  #cccccc;
#         }    #T_3228e95e_e10c_11e8_ace1_80ce6226d47arow1_col4 {
#             background-color:  #b2b2b2;
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
#           Metoda  Liczba składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2.0  Regresja logistyczna        0.65  0.74
# 1            LDA                2.0  Regresja logistyczna        0.73  0.63
# 2            NMF                2.0  Regresja logistyczna        0.60  1.09
# 3            PCA                4.0  Regresja logistyczna        0.84  0.30
# 4            LDA                4.0  Regresja logistyczna        0.83  0.34
# 5            NMF                4.0  Regresja logistyczna        0.77  0.61
# 6            PCA                2.0                   SVM        0.78  0.50
# 7            LDA                2.0                   SVM        0.84  0.34
# 8            NMF                2.0                   SVM        0.70  0.62
# 9            PCA                4.0                   SVM        0.87  0.34
# 10           LDA                4.0                   SVM        0.85  0.43
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)
# Out:
# d:\private-projects\venv\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
#           Metoda Liczba_składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2_  Regresja logistyczna        0.65  0.74
# 1            LDA                2_  Regresja logistyczna        0.73  0.63
# 2            NMF                2_  Regresja logistyczna        0.60  1.09
# 3            PCA                4_  Regresja logistyczna        0.84  0.30
# 4            LDA                4_  Regresja logistyczna        0.83  0.34
# 5            NMF                4_  Regresja logistyczna        0.77  0.61
# 6            PCA                2_                   SVM        0.78  0.50
# 7            LDA                2_                   SVM        0.84  0.34
# 8            NMF                2_                   SVM        0.70  0.62
# 9            PCA                4_                   SVM        0.87  0.34
# 10           LDA                4_                   SVM        0.85  0.43
# ...

# %%
import seaborn as sns
cm = sns.light_palette("grey", as_cmap=True)
pretty_report_df = pretty_report_df.style.background_gradient(cmap=cm)
pretty_report_df
# Out:
# <style  type="text/css" >
#     #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow0_col3 {
#             background-color:  #e2e2e2;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow0_col4 {
#             background-color:  #a6a6a6;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow0_col5 {
#             background-color:  #e2e2e2;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow0_col6 {
#             background-color:  #e2e2e2;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow0_col7 {
#             background-color:  #e2e2e2;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow1_col3 {
#             background-color:  #cccccc;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow1_col4 {
#             background-color:  #b2b2b2;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow1_col5 {
#             background-color:  #cccccc;
#         }    #T_f704f6f8_e10d_11e8_97c2_80ce6226d47arow1_col6 {
#             background-color:  #cccccc;
# ...

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e3db37b617cd> in <module>
#       1 import pandas as pd
#       2 roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
# ----> 3 pretty_report_df.round(roundings)
#
# AttributeError: 'Styler' object has no attribute 'round'

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)

import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)

import seaborn as sns
cm = sns.light_palette("grey", as_cmap=True)
pretty_report_df = pretty_report_df.style.background_gradient(cmap=cm)
pretty_report_df
# Out:
# d:\private-projects\venv\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# <style  type="text/css" >
#     #T_45650f9a_e10e_11e8_b084_80ce6226d47arow0_col3 {
#             background-color:  #e2e2e2;
#         }    #T_45650f9a_e10e_11e8_b084_80ce6226d47arow0_col4 {
#             background-color:  #a6a6a6;
#         }    #T_45650f9a_e10e_11e8_b084_80ce6226d47arow0_col5 {
#             background-color:  #e2e2e2;
#         }    #T_45650f9a_e10e_11e8_b084_80ce6226d47arow0_col6 {
#             background-color:  #e2e2e2;
#         }    #T_45650f9a_e10e_11e8_b084_80ce6226d47arow0_col7 {
#             background-color:  #e2e2e2;
#         }    #T_45650f9a_e10e_11e8_b084_80ce6226d47arow1_col3 {
# ...

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)

import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
# d:\private-projects\venv\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
#           Metoda Liczba_składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2   Regresja logistyczna        0.65  0.74
# 1            LDA                2   Regresja logistyczna        0.73  0.63
# 2            NMF                2   Regresja logistyczna        0.60  1.09
# 3            PCA                4   Regresja logistyczna        0.84  0.30
# 4            LDA                4   Regresja logistyczna        0.83  0.34
# 5            NMF                4   Regresja logistyczna        0.77  0.61
# 6            PCA                2                    SVM        0.78  0.50
# ...

# %%
pretty_report_df.style.background_gradient(cmap=cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f4d56be14fb6> in <module>
# ----> 1 pretty_report_df.style.background_gradient(cmap=cm)
#
# NameError: name 'cm' is not defined

# %%
import seaborn as sns
cm = sns.light_palette("grey", as_cmap=True)
pretty_report_df = pretty_report_df.style.background_gradient(cmap=cm)
pretty_report_df
# Out:
# <style  type="text/css" >
#     #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow0_col3 {
#             background-color:  #e2e2e2;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow0_col4 {
#             background-color:  #a6a6a6;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow0_col5 {
#             background-color:  #e2e2e2;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow0_col6 {
#             background-color:  #e2e2e2;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow0_col7 {
#             background-color:  #e2e2e2;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow1_col3 {
#             background-color:  #cccccc;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow1_col4 {
#             background-color:  #b2b2b2;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow1_col5 {
#             background-color:  #cccccc;
#         }    #T_12b65c5e_e10f_11e8_bc84_80ce6226d47arow1_col6 {
#             background-color:  #cccccc;
# ...

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e3db37b617cd> in <module>
#       1 import pandas as pd
#       2 roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
# ----> 3 pretty_report_df.round(roundings)
#
# AttributeError: 'Styler' object has no attribute 'round'

# %%
from summary_report import SummaryReport
sr = SummaryReport()
report_df = sr.generate_summary_report(run_id='2018-11-05 130921')
pretty_report_df = sr.make_report_pretty(report_df)
# Out:
# d:\private-projects\venv\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
import pandas as pd
roundings = pd.Series([ 2, 2, 2, 2, 2], index=['Dokładność', 'Błąd', 'Precyzja', 'Pełność', 'Wynik F1'])
pretty_report_df.round(roundings)
# Out:
#           Metoda Liczba_składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2   Regresja logistyczna        0.65  0.74
# 1            LDA                2   Regresja logistyczna        0.73  0.63
# 2            NMF                2   Regresja logistyczna        0.60  1.09
# 3            PCA                4   Regresja logistyczna        0.84  0.30
# 4            LDA                4   Regresja logistyczna        0.83  0.34
# 5            NMF                4   Regresja logistyczna        0.77  0.61
# 6            PCA                2                    SVM        0.78  0.50
# 7            LDA                2                    SVM        0.84  0.34
# 8            NMF                2                    SVM        0.70  0.62
# 9            PCA                4                    SVM        0.87  0.34
# 10           LDA                4                    SVM        0.85  0.43
# ...

# %%
import seaborn as sns
cm = sns.light_palette("grey", as_cmap=True)
pretty_report_df.style.background_gradient(cmap=cm)
pretty_report_df
# Out:
#           Metoda Liczba_składowych          Klasyfikator  Dokładność  \
# 0            PCA                2   Regresja logistyczna    0.654545
# 1            LDA                2   Regresja logistyczna    0.727273
# 2            NMF                2   Regresja logistyczna    0.600000
# 3            PCA                4   Regresja logistyczna    0.836364
# 4            LDA                4   Regresja logistyczna    0.827273
# 5            NMF                4   Regresja logistyczna    0.772727
# 6            PCA                2                    SVM    0.781818
# 7            LDA                2                    SVM    0.836364
# 8            NMF                2                    SVM    0.700000
# 9            PCA                4                    SVM    0.872727
# 10           LDA                4                    SVM    0.854545
# 11           NMF                4                    SVM    0.827273
# 12           PCA                2       Drzewo decyzyjne    0.709091
# ...

# %%
pretty_report_df.round(roundings)
# Out:
#           Metoda Liczba_składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2   Regresja logistyczna        0.65  0.74
# 1            LDA                2   Regresja logistyczna        0.73  0.63
# 2            NMF                2   Regresja logistyczna        0.60  1.09
# 3            PCA                4   Regresja logistyczna        0.84  0.30
# 4            LDA                4   Regresja logistyczna        0.83  0.34
# 5            NMF                4   Regresja logistyczna        0.77  0.61
# 6            PCA                2                    SVM        0.78  0.50
# 7            LDA                2                    SVM        0.84  0.34
# 8            NMF                2                    SVM        0.70  0.62
# 9            PCA                4                    SVM        0.87  0.34
# 10           LDA                4                    SVM        0.85  0.43
# ...

# %%
import Pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3400ffdb6323> in <module>
# ----> 1 import Pandas as pd
#
# ModuleNotFoundError: No module named 'Pandas'

# %%
import pandas as pd

# %%
unpickled_df = pd.read_pickle('D:\\private-projects\\linear-dim-reduction\\summary_report\\pretty_pickle.dat')

# %%
unpickled_df
# Out:
#           Metoda Liczba_składowych          Klasyfikator  Dokładność  Błąd  \
# 0            PCA                2   Regresja logistyczna        0.65  0.74
# 1            LDA                2   Regresja logistyczna        0.73  0.63
# 2            NMF                2   Regresja logistyczna        0.60  1.09
# 3            PCA                4   Regresja logistyczna        0.84  0.30
# 4            LDA                4   Regresja logistyczna        0.83  0.34
# 5            NMF                4   Regresja logistyczna        0.77  0.61
# 6            PCA                2                    SVM        0.78  0.50
# 7            LDA                2                    SVM        0.84  0.34
# 8            NMF                2                    SVM        0.70  0.62
# 9            PCA                4                    SVM        0.87  0.34
# 10           LDA                4                    SVM        0.85  0.43
# ...

# %%
pretty_report_df  = pd.read_pickle('D:\\private-projects\\linear-dim-reduction\\summary_report\\pretty_pickle.dat')
import seaborn as sns
cm = sns.light_palette("grey", as_cmap=True)
pretty_report_df = pretty_report_df.style.background_gradient(cmap=cm)
pretty_report_df
# Out:
# <style  type="text/css" >
#     #T_cc18a564_e17d_11e8_9671_80ce6226d47arow0_col3 {
#             background-color:  #a8a8a8;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow0_col4 {
#             background-color:  #d3d3d3;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow0_col5 {
#             background-color:  #a5a5a5;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow0_col6 {
#             background-color:  #b4b4b4;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow0_col7 {
#             background-color:  #b3b3b3;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow1_col3 {
#             background-color:  #9a9a9a;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow1_col4 {
#             background-color:  #dbdbdb;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow1_col5 {
#             background-color:  #9a9a9a;
#         }    #T_cc18a564_e17d_11e8_9671_80ce6226d47arow1_col6 {
#             background-color:  #9a9a9a;
# ...
